# %% [markdown]
# <a href="https://colab.research.google.com/github/moonjungh/python_class/blob/main/%EC%82%AC%EC%9A%A9%EC%9E%90_%EC%A0%95%EC%9D%98_%ED%95%A8%EC%88%98_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C(%EC%8B%A4%EC%8A%B5%EC%9A%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [문제1] 두 수를 입력받아 사용자 정의 함수로 사칙 연산을 수행하는 프로그램을 작성해보자.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#              변수명             자료형                     설명
# 1.
# 2.
# 3.

# %% [markdown]
# **[문제2] 섭취한 음식의 이름과 칼로리를 받아서 해당 칼로리를 소모하기 위해 걸어야 하는 시간을 알려 주는 프로그램을 작성해 보자.(단, 1시간 걸으면 250칼로리 소모된다고 가정한다.)**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#              변수명             자료형                     설명
# 1.
# 2.
# 3.
# 4.
# 5.
