# %% [markdown]
# <a href="https://colab.research.google.com/github/moonjungh/python_class/blob/main/%EC%84%A0%ED%83%9D%EC%A0%95%EB%A0%AC(%EC%A0%95%EB%8B%B5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# 출처:https://terms.naver.com/entry.naver?docId=2270435&cid=51173&categoryId=51173

# %%
li = [5,3,4,2,6,1]

for i in range(len(li)):
    print(li)
    index = i
    for j in range(i,len(li)):
        if li[index] > li[j]:
            index = j
    li[i],li[index] = li[index],li[i]
# Out:
# [5, 3, 4, 2, 6, 1]
# [1, 3, 4, 2, 6, 5]
# [1, 2, 4, 3, 6, 5]
# [1, 2, 3, 4, 6, 5]
# [1, 2, 3, 4, 6, 5]
# [1, 2, 3, 4, 5, 6]
