# %% [markdown]
# <a href="https://colab.research.google.com/github/moonjungh/python_class/blob/main/%EB%B0%98%EB%B3%B5%EA%B5%AC%EC%A1%B0_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C(%EC%8B%A4%EC%8A%B5%EC%9A%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **문제1) 입력된 정수가 0이 아니면 입력된 정수값을 출력하고, 0이 입력되면 출력을 중단해보자.**
#
# ---
# ![화면 캡처 2022-08-19 010710.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **문제2) 정수(0 ~ 100) 1개를 입력받아 0부터 그 수까지 순서대로 출력해보자.**
#
#
# ---
# ![화면 캡처 2022-08-19 012656.jpg](data:image/jpeg;base64,...)

# %%
 # while문 이용

# %%
# range문 이용

# %% [markdown]
# **문제3)정수(1 ~ 100) 1개가 입력되었을 때 1만큼씩 줄이면서 카운트 다운 수가 0이 될 때까지 한 줄에 1개씩 출력한다.**
#
#
# ---
# ![화면 캡처 2022-08-19 013407.jpg](data:image/jpeg;base64,...)

# %%
# n = n-1  (n에 저장되어있던 값에서 1만큼 뺀 후, 그 값을 다시 n에 저장시킨다.)

# %% [markdown]
# **문제4) 정수(1 ~ 100) 1개를 입력받아 1부터 그 수까지 짝수의 합을 구해보자.**
#
# [참고]
# while 이나 for 반복실행구조를 이용할 수 있다.
# 다른 방법이나 while 반복실행구조를 이용해서도 성공시켜 보자.

# %% [markdown]
# **문제5) 영문 소문자 'q'가 입력될 때까지 입력한 문자를 계속 출력하는 프로그램을 작성해보자.**

# %% [markdown]
# **문제6) n,m 값을 입력받아 1부터 n까지, 1부터 m까지 숫자가 적힌 서로 다른 주사위 2개를 던졌을 때, 나올 수 있는 모든 경우를 출력해보자.(for, range 이용)**

# %% [markdown]
# **문제7) 입력받은 수까지 3,6,9 게임을 진행한 결과를 출력해보자. 3,6,9가 들어간 수를 불러야 할 상황에는 "짝"을 3,6,9가 두 번 들어간 수 일때는 "짝짝"을 출력하도록 한다.**
#
# * 3 6 9 게임은? 여러 사람이 순서를 정한 후, 순서대로 수를 부르는 게임이다. 만약 3, 6, 9 가 들어간 수를 자신이 불러야 하는 상황이라면, 수를 부르는 대신 박수를 한번 쳐야 한다.(33,66,99와 같이 3,6,9가 두 번 들어간 수 일때, "짝짝"과 같이 박수를 두 번 치는 형태도 있다.)

# %%
# 방법1:  i%10==3 or i%10==6 or i%10==9

# %%
# 방법2: for i in range(1, n + 1)

# %%
# 33,66,99일때 "짝짝"을 출력하기 포함

# %% [markdown]
# **문제8) 입력받은 정수보다 작을 동안만 1, 2, 3 ... 을 순서대로 계속 더해 합을 구한다고 할 때 어디까지 더해야 입력한 수보다 작거나 같아지는지 출력하는 프로그램을 작성해보자.**
#
# 예를 들어, 57을 입력하면 1+2+3+...+8+9+10=55 이므로 10을 출력한다.
