# %% [markdown]
# <a href="https://colab.research.google.com/github/moonjungh/python_class/blob/main/%EB%B2%84%EB%B8%94%EC%A0%95%EB%A0%AC(%EC%8B%A4%EC%8A%B5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [해설]
#
# 1라인: 정렬되지 않은 임의의 리스트를 선언하였다.
#
# 2라인: 정렬전 리스트를 출력
#
# 3라인: 버블 정렬을 위한 바깥쪽 for문. 안쪽 for문의 범위를 줄이는 역할
#
# 4라인: 버블 정렬은 가장 큰 수가 뒤로 가게 된다. 이미 가장 큰 수로 정렬된 인덱스는 제외하고 범위를 잡아야 한다.
#
# 5~6라인: 검사하고자 하는 인덱스와 그 인덱스+1 위치에 있는 값을 비교하여 왼쪽이 더 크다면 두 값의 위치를 교환한다.
